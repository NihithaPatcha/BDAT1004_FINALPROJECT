# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import requests
import time
while True:
    r = requests.get("https://datausa.io/api/data?drilldowns=Nation&measures=Population")
    if r.status_code == 200:
        data = r.json()
        print(data)
        time.sleep(60)
    else:
        exit()
# Out:
# {'data': [{'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2019, 'Year': '2019', 'Population': 328239523, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2018, 'Year': '2018', 'Population': 327167439, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2017, 'Year': '2017', 'Population': 325719178, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2016, 'Year': '2016', 'Population': 323127515, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2015, 'Year': '2015', 'Population': 321418821, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2014, 'Year': '2014', 'Population': 318857056, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2013, 'Year': '2013', 'Population': 316128839, 'Slug Nation': 'united-states'}], 'source': [{'measures': ['Population'], 'annotations': {'source_name': 'Census Bureau', 'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.', 'dataset_name': 'ACS 1-year Estimate', 'dataset_link': 'http://www.census.gov/programs-surveys/acs/', 'table_id': 'B01003', 'topic': 'Diversity', 'subtopic': 'Demographics'}, 'name': 'acs_yg_total_population_1', 'substitutions': []}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bcecb5b0031c> in <module>
#       6         data = r.json()
#       7         print(data)
# ----> 8         time.sleep(60)
#       9     else:
#      10         exit()
#
# KeyboardInterrupt:

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\bhavy\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\bhavy\anaconda3\lib\site-packages (from pymongo[srv]) (2.2.1)

# %%
import requests
import time
from pymongo import MongoClient

client = MongoClient("mongodb+srv://Bhavya1:bhavya@cluster0.ywseg.mongodb.net/mydatabase?ss1 = true&ss1_cert_reqs=CERT_NONE")
db = client.get_database('mydatabase')
records = db.Sample

while True:
    r = requests.get("https://datausa.io/api/data?drilldowns=Nation&measures=Population")
    if r.status_code == 200:
        data = r.json()
        print(data)
        records.insert_one(data)
        time.sleep(60)
    else:
        exit()
# Out:
# {'data': [{'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2019, 'Year': '2019', 'Population': 328239523, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2018, 'Year': '2018', 'Population': 327167439, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2017, 'Year': '2017', 'Population': 325719178, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2016, 'Year': '2016', 'Population': 323127515, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2015, 'Year': '2015', 'Population': 321418821, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2014, 'Year': '2014', 'Population': 318857056, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2013, 'Year': '2013', 'Population': 316128839, 'Slug Nation': 'united-states'}], 'source': [{'measures': ['Population'], 'annotations': {'source_name': 'Census Bureau', 'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.', 'dataset_name': 'ACS 1-year Estimate', 'dataset_link': 'http://www.census.gov/programs-surveys/acs/', 'table_id': 'B01003', 'topic': 'Diversity', 'subtopic': 'Demographics'}, 'name': 'acs_yg_total_population_1', 'substitutions': []}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ab48f6d0bb15> in <module>
#      12         data = r.json()
#      13         print(data)
# ---> 14         records.insert_one(data)
#      15         time.sleep(60)
#      16     else:
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     604         write_concern = self._write_concern_for(session)
#     605         return InsertOneResult(
# --> 606             self._insert_one(
#     607                 document,
#     608                 ordered=True,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     545             _check_write_command_response(result)
#     546
# --> 547         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     548
#     549         if not isinstance(doc, RawBSONDocument):
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1397         """Internal retryable write helper."""
#    1398         with self._tmp_session(session) as s:
# -> 1399             return self._retry_with_session(retryable, func, s, None)
#    1400
#    1401     def __eq__(self, other: Any) -> bool:
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1284             retryable and self.options.retry_writes and session and not session.in_transaction
#    1285         )
# -> 1286         return self._retry_internal(retryable, func, session, bulk)
#    1287
#    1288     def _retry_internal(self, retryable, func, session, bulk):
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1309                     session is not None and server.description.retryable_writes_supported
#    1310                 )
# -> 1311                 with self._get_socket(server, session) as sock_info:
#    1312                     max_wire_version = sock_info.max_wire_version
#    1313                     if retryable and not supports_session:
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_socket(self, server, session)
#    1154                 yield session._pinned_connection
#    1155                 return
# -> 1156             with server.get_socket(handler=err_handler) as sock_info:
#    1157                 # Pin this session to the selected server or connection.
#    1158                 if in_txn and server.description.server_type in (
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in get_socket(self, handler)
#    1377             listeners.publish_connection_check_out_started(self.address)
#    1378
# -> 1379         sock_info = self._get_socket()
#    1380         if self.enabled_for_cmap:
#    1381             listeners.publish_connection_checked_out(self.address, sock_info.id)
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in _get_socket(self)
#    1487                 else:  # We need to create a new connection
#    1488                     try:
# -> 1489                         sock_info = self.connect()
#    1490                     finally:
#    1491                         with self._max_connecting_cond:
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in connect(self)
#    1345         try:
#    1346             if self.handshake:
# -> 1347                 sock_info.hello()
#    1348                 self.is_writable = sock_info.is_writable
#    1349
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in hello(self)
#     598
#     599     def hello(self):
# --> 600         return self._hello(None, None, None)
#     601
#     602     def _hello(self, cluster_time, topology_version, heartbeat_frequency):
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in _hello(self, cluster_time, topology_version, heartbeat_frequency)
#     632             auth_ctx = None
#     633
# --> 634         doc = self.command("admin", cmd, publish_events=False, exhaust_allowed=awaitable)
#     635         hello = Hello(doc, awaitable=awaitable)
#     636         self.is_writable = hello.is_writable
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     768         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     769         except BaseException as error:
# --> 770             self._raise_connection_failure(error)
#     771
#     772     def send_message(self, message, max_doc_size):
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     741             self._raise_if_not_writable(unacknowledged)
#     742         try:
# --> 743             return command(
#     744                 self,
#     745                 dbname,
#
# ~\anaconda3\lib\site-packages\pymongo\network.py in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     148             response_doc = {"ok": 1}
#     149         else:
# --> 150             reply = receive_message(sock_info, request_id)
#     151             sock_info.more_to_come = reply.more_to_come
#     152             unpacked_docs = reply.unpack_response(
#
# ~\anaconda3\lib\site-packages\pymongo\network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# ~\anaconda3\lib\site-packages\pymongo\network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
list(records.find({}))
# Out:
# [{'_id': ObjectId('62552970cbb0e75ef9ce1ce0'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('62552a3d5a6f830ab148ca8a'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257de42e46075a056fc6dc4'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257de7fe46075a056fc6dc5'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257debbe46075a056fc6dc6'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257def7e46075a056fc6dc7'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257df33e46075a056fc6dc8'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257df70e46075a056fc6dc9'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257dface46075a056fc6dca'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257dfe8e46075a056fc6dcb'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e025e46075a056fc6dcc'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e061e46075a056fc6dcd'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e09de46075a056fc6dce'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e0dae46075a056fc6dcf'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e116e46075a056fc6dd0'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e153e46075a056fc6dd1'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e18fe46075a056fc6dd2'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e1cbe46075a056fc6dd3'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e207e46075a056fc6dd4'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e244e46075a056fc6dd5'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e280e46075a056fc6dd6'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e2bce46075a056fc6dd7'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e2f8e46075a056fc6dd8'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e335e46075a056fc6dd9'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e374e46075a056fc6dda'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e3b1e46075a056fc6ddb'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e3ede46075a056fc6ddc'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6257e429e46075a056fc6ddd'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
# ...
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6258089ae46075a056fc6e77'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('625808d6e46075a056fc6e78'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('62580912e46075a056fc6e79'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6258094fe46075a056fc6e7a'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('6258098ce46075a056fc6e7b'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('625809c8e46075a056fc6e7c'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('62580a04e46075a056fc6e7d'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('62580a41e46075a056fc6e7e'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]},
#  {'_id': ObjectId('62580a7de46075a056fc6e7f'),
#   'data': [{'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2019,
#     'Year': '2019',
#     'Population': 328239523,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2018,
#     'Year': '2018',
#     'Population': 327167439,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2017,
#     'Year': '2017',
#     'Population': 325719178,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2016,
#     'Year': '2016',
#     'Population': 323127515,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2015,
#     'Year': '2015',
#     'Population': 321418821,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2014,
#     'Year': '2014',
#     'Population': 318857056,
#     'Slug Nation': 'united-states'},
#    {'ID Nation': '01000US',
#     'Nation': 'United States',
#     'ID Year': 2013,
#     'Year': '2013',
#     'Population': 316128839,
#     'Slug Nation': 'united-states'}],
#   'source': [{'measures': ['Population'],
#     'annotations': {'source_name': 'Census Bureau',
#      'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#      'dataset_name': 'ACS 1-year Estimate',
#      'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#      'table_id': 'B01003',
#      'topic': 'Diversity',
#      'subtopic': 'Demographics'},
#     'name': 'acs_yg_total_population_1',
#     'substitutions': []}]}]
